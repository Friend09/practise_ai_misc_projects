# %% [markdown]
# # Build an agent to identify the most predictive set of features in a Linear Model using smolagents

# %% [markdown]
# [medium](https://nayakpplaban.medium.com/build-an-agent-to-identify-the-most-predictive-set-of-features-in-a-linear-model-using-smolagents-d0d44ac7e721)

# %% [markdown]
# ## SETUP

# %%
import os

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## BUILD AGENT

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, LiteLLMModel, HfApiModel

deepseek_model = LiteLLMModel(model_id="ollama/deepseek-r1:1.5b")
codellama_model = LiteLLMModel(model_id="ollama/codellama:7b")
llama_model = LiteLLMModel(model_id="ollama/llama3.2:latest")
openai_model = HfApiModel()

agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=openai_model)

# %%
# agent.run(
#     "How many seconds would it take for a leopard at full speed to run through Pont des Arts?"
# )

# %%
task = """
1. Load the Diabetes dataset from the 'sklearn' library using the following code:
        from sklearn.datasets import load_diabetes
        import pandas as pd

        # Load the dataset
        data, target = load_diabetes(return_X_y=True, as_frame=False)

        # Create a DataFrame
        df = pd.DataFrame(data, columns=load_diabetes().feature_names)
        df['target'] = target
2. Split data with a train/test split of 75%/25%
3. Create a linear regression model on the training data predicting the target variable using the "sklearn" or "statsmodels" library.
4. Execute on a strategy of combination of up to 3 predictors that attains the lowest root mean square error (RMSE) on the testing data.
   (You can't use the target variable).
5. Use feature engineering as needed to improve model performance.
6. Based on the lowest RMSE of each model for the testing data, provide a final list of predictors for the top 5 models
7. Only Output The predictors as a table in Markdown format.Do not provide any other Reasoning or explanation.
"""

# %%
feature_selection_agent = CodeAgent(
    tools=[DuckDuckGoSearchTool()],
    additional_authorized_imports=["pandas", "statsmodels", "sklearn", "numpy", "json"],
    model=llama_model,
)

result = feature_selection_agent.run(task)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ 1. Load the Diabetes dataset from the 'sklearn' library using the following code:                               │
# │         from sklearn.datasets import load_diabetes                                                              │
# │         import pandas as pd                                                                                     │
# │                                                                                                                 │
# │         # Load the dataset                                                                                      │
# │         data, target = load_diabetes(return_X_y=True, as_frame=False)                                           │
# ...

# %%
print(result)
# Out:
# **Diabetes Regression Model**
# ...
#
# ### Load Data and Split into Training/Testing Sets
#
# ```python
# from sklearn.datasets import load_diabetes
# import pandas as pd
# from sklearn.model_selection import train_test_split
#
# # Load the dataset
# data, target = load_diabetes(return_X_y=True, as_frame=False)
#
# # Create a DataFrame
# df = pd.DataFrame(data, columns=data.columns)
# df['target'] = target
#
# # Split data into training and testing sets (75% training, 25% testing)
# X_train, X_test, y_train, y_test = train_test_split(df.drop('target', axis=1), df['target'], test_size=0.25, random_state=42)
# ```
#
# ### Define Linear Regression Models with Feature Engineering
#
# ```python
# from sklearn.linear_model import LinearRegression
# import numpy as np
# from sklearn.preprocessing import StandardScaler
# from statsmodels.formula.api import ols
# import statsmodels.api as sm
#
# # Define a function to create and train linear regression models with feature engineering
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 result.content
#
# AttributeError: 'AgentText' object has no attribute 'content'
